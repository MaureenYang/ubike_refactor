# %%
import numpy as np                               # vectors and matrices
import pandas as pd                              # tables and data manipulations
import matplotlib.pyplot as plt                  # plots
import math
import os

srcfilepath = "csvfile/source/"
filesinpath = os.listdir(srcfilepath)
parsed_file = []
counter = 0
final_df = pd.DataFrame()

# %%
# %%time
for f in sorted(filesinpath):
    print(f)
    str_file = srcfilepath + f
    df = pd.read_csv(str_file)
    df = df.rename(columns={"Unnamed: 0": "time"})

    emptyidx=[]
    for x in df.index:
        if df.time[x] is np.nan:
            emptyidx = emptyidx + [x]

    df = df.drop(index = emptyidx)
    df = df.drop(columns = ['act','lat','lng','tot','SeaPres','GloblRad','CloudA','td'])

    df['time'] = pd.to_datetime(df['time'], format='%Y/%m/%d %H%M%S', errors='ignore')
    df = df.set_index(pd.DatetimeIndex(df['time']))
    df = df.drop_duplicates()
    float_idx = ['sno','HUMD','bemp','sbi','PRES', 'TEMP', 'WDIR', 'H_24R', 'WDSE', 'WSGust', 'PrecpHour', 'UVI', 'Visb', 'WDGust']

    df[float_idx] = df[float_idx].astype('float')

    df['bemp'] = df['bemp'].apply(lambda x: round(x, 0))
    df['sbi'] = df['sbi'].apply(lambda x: round(x, 0))

    fill_past_mean_tag = ['bemp','sbi']
    interpolate_tag = ['TEMP','WDIR','H_24R','sno','PRES','HUMD','WDSE'] #CloudA
    fillzero_tag = ['UVI'] #GloblRad
    
    for tag in fill_past_mean_tag:
        dfl = []
        ndf = df[tag]
        for month in range(0,11):
            x = month%3
            y = math.floor(month/3)
            data = ndf[ndf.index.month == (month+2)]
            idx = data.index[data.apply(np.isnan)]

            #get mean of each weekday
            meanss = []
            for wkday in range(0,7):
                for hr in range(0,24):
                    means = round(data[(data.index.hour == hr)&(data.index.weekday == wkday)].mean())
                    meanss = meanss + [means]

            #replace na data
            for i in idx:
                data.loc[i] = meanss[i.weekday()*23 + i.hour]

            dfl = dfl + [data]

        new_df = pd.concat(dfl)
        df[tag]= new_df.values


    for tag in interpolate_tag:
        df[tag] = df[tag].interpolate()


    for tag in fillzero_tag:
        df[tag] = df[tag].fillna(0)

    df['weekday'] = df.index.weekday
    df['hours'] = df.index.hour

    #can be replace by list of anything
    from datetime import date
    from workalendar.asia import Taiwan
    cal = Taiwan()
    holidayidx = []
    for t in cal.holidays(2018):
        date_str = t[0].strftime("%Y-%m-%d")
        holidayidx = holidayidx + [date_str]

    df['holiday'] = df.index.isin(holidayidx)

    for tag in ['bemp','sbi']:

        for i in range(1,13):
            df[tag+'_'+str(i)+'h'] = df[tag].shift(i)

        for i in range(1,8):
            df[tag+'_'+str(i)+'d'] = df[tag].shift(i*24)


        ndf = df
        ndf['predict_hour'] = 1
        for tag in ['bemp','sbi']:
            ndf['y_' + tag] = df[tag].shift(-1)

        for i in range(1,13):
            ndf2 = df
            ndf2['predict_hour'] = i
            for tag in ['bemp','sbi']:
                ndf2['y_' + tag] = df[tag].shift(-i)
                #ndf2.to_csv("csvfile/parsed/" + "new_" + newfilename +"_predict_"+tag+"_"+str(i)+"h.csv")
            ndf = ndf.append(ndf2,ignore_index=True)

        ndf = ndf.dropna()

        ndf["time"] = pd.to_datetime(ndf["time"], format="%Y-%m-%d %H:%M")
        ndf.index = ndf["time"]
        #ndf.drop("time", 1, inplace=True)

        ndf = ndf["20180301":"20181031"]

        #just one file
        final_df  = final_df.append(ndf,ignore_index=True)
# Out:
# /usr/local/Cellar/jupyterlab/1.2.4/libexec/lib/python3.7/site-packages/skyfield_data/expirations.py:25: RuntimeWarning: The file deltat.preds has expired. Please upgrade your version of `skyfield-data` or expect computation errors
#   RuntimeWarning
# /usr/local/Cellar/jupyterlab/1.2.4/libexec/lib/python3.7/site-packages/skyfield_data/expirations.py:25: RuntimeWarning: The file deltat.data has expired. Please upgrade your version of `skyfield-data` or expect computation errors
#   RuntimeWarning
# /usr/local/Cellar/jupyterlab/1.2.4/libexec/lib/python3.7/site-packages/skyfield_data/expirations.py:25: RuntimeWarning: The file Leap_Second.dat has expired. Please upgrade your version of `skyfield-data` or expect computation errors
#   RuntimeWarning
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-afec0723762f> in <module>
#      67     cal = Taiwan()
#      68     holidayidx = []
# ---> 69     for t in cal.holidays(2018):
#      70         date_str = t[0].strftime("%Y-%m-%d")
#      71         holidayidx = holidayidx + [date_str]
#
# /usr/local/Cellar/jupyterlab/1.2.4/libexec/lib/python3.7/site-packages/workalendar/core.py in holidays(self, year)
#      87
#      88         # Here we process the holiday specific calendar
# ---> 89         temp_calendar = tuple(self.get_calendar_holidays(year))
#      90
#      91         # it is sorted
#
# /usr/local/Cellar/jupyterlab/1.2.4/libexec/lib/python3.7/site-packages/workalendar/core.py in get_calendar_holidays(self, year)
#     668         """
#     669         # Unshifted days are here:
# --> 670         days = super().get_calendar_holidays(year)
#     671         if self.shift_sunday_holidays:
#     672             days_to_inspect = copy(days)
#
# /usr/local/Cellar/jupyterlab/1.2.4/libexec/lib/python3.7/site-packages/workalendar/core.py in get_calendar_holidays(self, year)
#      75         If you want to override this, please make sure that it **must** return
#      76         a list of tuples (date, holiday_name)."""
# ---> 77         return self.get_fixed_holidays(year) + self.get_variable_days(year)
#      78
#      79     def holidays(self, year=None):
#
# /usr/local/Cellar/jupyterlab/1.2.4/libexec/lib/python3.7/site-packages/workalendar/asia/taiwan.py in get_variable_days(self, year)
#      22         # Qingming begins when the sun reaches the celestial
#      23         # longitude of 15° (usually around April 4th or 5th)
# ---> 24         qingming = solar_term(year, 15, 'Asia/Taipei')
#      25
#      26         days.extend([
#
# /usr/local/Cellar/jupyterlab/1.2.4/libexec/lib/python3.7/site-packages/workalendar/astronomy.py in solar_term(year, degrees, timezone)
#      83     earth = planets['earth']
#      84     sun = planets['sun']
# ---> 85     ts = load.timescale()
#      86     tz = pytz.timezone(timezone)
#      87
#
# /usr/local/Cellar/jupyterlab/1.2.4/libexec/lib/python3.7/site-packages/skyfield/iokit.py in timescale(self, delta_t, builtin)
#     312         else:
#     313             try:
# --> 314                 data = self('deltat.data')
#     315                 preds = self('deltat.preds')
#     316             except IOError as e:
#
# /usr/local/Cellar/jupyterlab/1.2.4/libexec/lib/python3.7/site-packages/skyfield/iokit.py in __call__(self, filename)
#     201
#     202         self._log('  Downloading: {0}', url)
# --> 203         download(url, path, self.verbose)
#     204
#     205         if parser is not None:
#
# /usr/local/Cellar/jupyterlab/1.2.4/libexec/lib/python3.7/site-packages/skyfield/iokit.py in download(url, path, verbose, blocksize)
#     526         e2 = IOError('cannot get {0} because {1}'.format(url, e))
#     527         e2.__cause__ = None
# --> 528         raise e2
#     529     if verbose is None:
#     530         verbose = sys.stderr.isatty()
#
# OSError: cannot get ftp://cddis.nasa.gov/products/iers/deltat.data because <urlopen error ftp error: TimeoutError(60, 'Operation timed out')>
#
# Try opening the same URL in your browser to learn more about the problem.
# If you want to fall back on the timescale files that Skyfield ships with,
# try `.timescale(builtin=True)` instead.

# %%
pip install workalendar --upgrade
# Out:
# Collecting workalendar
#   Downloading workalendar-15.1.0-py3-none-any.whl (190 kB)
#      |████████████████████████████████| 190 kB 922 kB/s eta 0:00:01    |█████████████████▏              | 102 kB 922 kB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: python-dateutil in /usr/local/Cellar/jupyterlab/1.2.4/libexec/lib/python3.7/site-packages (from workalendar) (2.8.1)
# Requirement already satisfied, skipping upgrade: skyfield-data in /usr/local/Cellar/jupyterlab/1.2.4/libexec/lib/python3.7/site-packages (from workalendar) (0.1.0)
# Requirement already satisfied, skipping upgrade: setuptools>=1.0 in /usr/local/Cellar/jupyterlab/1.2.4/libexec/lib/python3.7/site-packages (from workalendar) (42.0.2)
# Collecting backports.zoneinfo; python_version < "3.9"
#   Using cached backports.zoneinfo-0.2.1-cp37-cp37m-macosx_10_14_x86_64.whl (35 kB)
# Requirement already satisfied, skipping upgrade: lunardate in /usr/local/Cellar/jupyterlab/1.2.4/libexec/lib/python3.7/site-packages (from workalendar) (0.2.0)
# Requirement already satisfied, skipping upgrade: skyfield in /usr/local/Cellar/jupyterlab/1.2.4/libexec/lib/python3.7/site-packages (from workalendar) (1.17)
# Requirement already satisfied, skipping upgrade: pyluach in /usr/local/Cellar/jupyterlab/1.2.4/libexec/lib/python3.7/site-packages (from workalendar) (1.0.1)
# Requirement already satisfied, skipping upgrade: pyCalverter in /usr/local/Cellar/jupyterlab/1.2.4/libexec/lib/python3.7/site-packages (from workalendar) (1.6.1)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /usr/local/Cellar/jupyterlab/1.2.4/libexec/lib/python3.7/site-packages (from python-dateutil->workalendar) (1.15.0)
# Requirement already satisfied, skipping upgrade: jplephem>=2.11 in /usr/local/Cellar/jupyterlab/1.2.4/libexec/lib/python3.7/site-packages (from skyfield->workalendar) (2.12)
# Requirement already satisfied, skipping upgrade: numpy in /usr/local/Cellar/jupyterlab/1.2.4/libexec/lib/python3.7/site-packages (from skyfield->workalendar) (1.18.0)
# Requirement already satisfied, skipping upgrade: sgp4>=2.2 in /usr/local/Cellar/jupyterlab/1.2.4/libexec/lib/python3.7/site-packages (from skyfield->workalendar) (2.3)
# Installing collected packages: backports.zoneinfo, workalendar
#   Attempting uninstall: workalendar
#     Found existing installation: workalendar 8.1.0
#     Uninstalling workalendar-8.1.0:
#       Successfully uninstalled workalendar-8.1.0
# Successfully installed backports.zoneinfo-0.2.1 workalendar-15.1.0
# WARNING: You are using pip version 20.0.2; however, version 21.0.1 is available.
# You should consider upgrading via the '/usr/local/Cellar/jupyterlab/1.2.4/libexec/bin/python3.7 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
